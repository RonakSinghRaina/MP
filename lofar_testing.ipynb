# %%
from lofar_data import load_lofar, preprocess
d = load_lofar()
print(d.summary())
# Out:
# train_images (7500, 512, 512, 1) float32  (RAW)
# train_masks  (7500, 512, 512, 1) bool  (AOFlagger)
# test_images  (109, 512, 512, 1) float32  (RAW)
# test_masks   (109, 512, 512, 1) bool  (HUMAN)
# clean_train_idx: 7356 usable training images
# leak_train_idx:  109 training images that are byte-identical to test images
# total on disk 9.29 GiB, but memory-mapped -- RAM use is ~0

# %%
from lofar_data import load_lofar, preprocess

d = load_lofar()

# %%
d.train_images    # (7500, 512, 512, 1)  was data[0]
d.train_masks     # (7500, 512, 512, 1)  was data[1]
d.test_images     # (109, 512, 512, 1)   was data[2]
d.test_masks      # (109, 512, 512, 1)   was data[3]
# Out:
# memmap([[[[False],
#           [False],
#           [False],
#           ...,
#           [False],
#           [False],
#           [False]],
#
#          [[False],
#           [False],
#           [False],
#           ...,
#           [False],
#           [False],
#           [False]],
#
#          [[False],
#           [False],
#           [False],
#           ...,
#           [False],
#           [False],
#           [False]],
#
#          ...,
#
#          [[False],
#           [False],
#           [False],
#           ...,
#           [ True],
#           [ True],
#           [ True]],
#
#          [[False],
#           [False],
#           [False],
#           ...,
#           [ True],
#           [ True],
#           [ True]],
#
#          [[False],
#           [False],
#           [False],
#           ...,
#           [False],
#           [False],
#           [False]]],
#
#
#         [[[False],
#           [False],
#           [False],
#           ...,
#           [False],
# ...

# %%
a=d.train_images[3]
import matplotlib.pyplot as plt
plt.matshow(a)

# %%
import matplotlib.pyplot as plt
plt.matshow(preprocess(d.train_images[5, :, :, 0]))   # now you see actual structure
plt.matshow(d.train_masks[5,:, :, 0])
